# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
titanic_train_data = pd.read_csv("train.csv")

# %%
titanic_train_data = titanic_train_data.drop(columns=["Cabin", "Name", "Ticket"])

# %%
fare_cats_bins = list(range(0, 301, 50))
fare_cats_bins_with_inf = fare_cats_bins + [np.inf]
titanic_train_data["Fare_cat"] = pd.cut(
    titanic_train_data["Fare"],
    include_lowest=True,
    bins=pd.Series(fare_cats_bins_with_inf),
    labels=pd.Series(fare_cats_bins),
)
titanic_train_data["Fare_cat"] = titanic_train_data["Fare_cat"].astype(int)

# %%
train_set, test_set = train_test_split(
    titanic_train_data,
    test_size=0.2,
    random_state=0,
    stratify=titanic_train_data["Fare_cat"],
)

# %%
y_train = train_set["Survived"]
X_train = train_set.drop(columns=["Survived"])

# %%
colums_with_missing_values = X_train.columns[X_train.isnull().any()]

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

numerical_imputer = SimpleImputer(strategy="median")
object_imputer = SimpleImputer(strategy="most_frequent")
oneHotEncoder = OneHotEncoder(
    handle_unknown="ignore", sparse_output=False, drop="first"
)

# %%
def getLogPlusOne(fare):
    return np.log(fare + 1)

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline

fare_transformer = Pipeline(
    steps=[
        (
            "log_plus_1",
            FunctionTransformer(
                getLogPlusOne, validate=True, feature_names_out="one-to-one"
            ),
        ),
        ("standard_scaler", StandardScaler()),
    ]
)

# %%
pipeline_numerical_imputer = Pipeline(
    steps=[("numerical_imputer", numerical_imputer), ("scaler", StandardScaler())]
)
pipeline_object_imputer = Pipeline(
    steps=[("object_imputer", object_imputer), ("one_hot_encode", oneHotEncoder)]
)
numerical_standard_pipeline = Pipeline(steps=[("scaler", StandardScaler())])
object_standard_pipeline = Pipeline(steps=[("one_hot_encoder", oneHotEncoder)])

# %%
from sklearn.compose import ColumnTransformer

columnTransformer = ColumnTransformer(
    [
        ("fare_transformer", fare_transformer, ["Fare"]),
        ("numerical_with_missing_vals", pipeline_numerical_imputer, ["Age"]),
        ("object_with_missing_vals", pipeline_object_imputer, ["Embarked"]),
        ("standard_object", object_standard_pipeline, ["Sex"]),
        (
            "standard_numeric",
            numerical_standard_pipeline,
            ["SibSp", "Parch", "Fare_cat"],
        ),
    ],
    remainder="passthrough",
)

# %%
columnTransformer = columnTransformer.fit(X_train)

# %%
X_train_transformed = columnTransformer.transform(X_train)

# %%
y_test = test_set["Survived"]
X_test = test_set.drop(columns=["Survived"])

# %%
X_test_transformed = columnTransformer.transform(X_test)

# %% [markdown]
# # Random Forest (winner)

# %%
from sklearn.ensemble import RandomForestClassifier

randomForest = RandomForestClassifier(
    n_estimators=50, criterion="entropy", random_state=0
)

# %%
randomForest.fit(X_train_transformed, y_train)
y_test_predict = randomForest.predict(X_test_transformed)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

print(confusion_matrix(y_test, y_test_predict, normalize="all"))
print(accuracy_score(y_test, y_test_predict, normalize=True))
# Out:
# [[0.57541899 0.06703911]
#  [0.09497207 0.26256983]]
# 0.8379888268156425

# %% [markdown]
# Perform random search for hyper params

# %%
from scipy.stats import randint, uniform

param_distributions = {
    "n_estimators": randint(low=50, high=1000),  # Number of trees in the forest
    "max_features": [
        "sqrt",
        "log2",
        None,
    ],  # Number of features to consider at each split
    "max_depth": randint(low=10, high=110),  # Maximum number of levels in a tree
    "min_samples_split": randint(
        low=2, high=20
    ),  # Minimum number of samples required to split a node
    "min_samples_leaf": randint(
        low=1, high=10
    ),  # Minimum number of samples required at each leaf node
    "bootstrap": [
        True,
        False,
    ],  # Whether bootstrap samples are used when building trees
    "criterion": ["gini", "entropy"],  # The function to measure the quality of a split
}

# %%
from sklearn.model_selection import RandomizedSearchCV

random_search = RandomizedSearchCV(
    estimator=randomForest,
    param_distributions=param_distributions,
    n_iter=100,  # Number of random combinations to try
    cv=5,  # 5-fold cross-validation
    verbose=2,  # Increase verbosity to see progress
    random_state=42,  # Set for reproducibility
    n_jobs=-1,  # Use all available CPU cores
)

# %%
# 4. Fit RandomizedSearchCV to your data
print("Performing randomized search...")
random_search.fit(X_train_transformed, y_train)

# 5. Print the best hyperparameters and the corresponding score
print("\nBest hyperparameters found:")
print(random_search.best_params_)

print("\nBest cross-validation score:")
print(random_search.best_score_)

# 6. Get the best estimator
best_random_forest = random_search.best_estimator_
print("\nBest Random Forest Classifier:")
print(best_random_forest)

# 7. Evaluate on the test set
y_pred = best_random_forest.predict(X_test_transformed)
from sklearn.metrics import accuracy_score, classification_report

print("\nAccuracy on test set:")
print(accuracy_score(y_test, y_pred))
print("\nClassification Report on test set:")
print(classification_report(y_test, y_pred))
# Out:
# Performing randomized search...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END bootstrap=True, criterion=entropy, max_depth=102, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=102, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=102, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=102, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=102, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=31, max_features=sqrt, min_samples_leaf=2, min_samples_split=13, n_estimators=463; total time=   0.6s
# [CV] END bootstrap=False, criterion=gini, max_depth=31, max_features=sqrt, min_samples_leaf=2, min_samples_split=13, n_estimators=463; total time=   0.6s
# [CV] END bootstrap=False, criterion=gini, max_depth=31, max_features=sqrt, min_samples_leaf=2, min_samples_split=13, n_estimators=463; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=73, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=363; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=31, max_features=sqrt, min_samples_leaf=2, min_samples_split=13, n_estimators=463; total time=   0.6s
# [CV] END bootstrap=False, criterion=gini, max_depth=31, max_features=sqrt, min_samples_leaf=2, min_samples_split=13, n_estimators=463; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=921; total time=   1.5s[CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=921; total time=   1.6s
#
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=921; total time=   1.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=921; total time=   1.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=921; total time=   1.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=73, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=363; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=73, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=363; total time=   0.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=73, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=363; total time=   0.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=73, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=363; total time=   0.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=616; total time=   0.7s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=616; total time=   0.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=616; total time=   0.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=616; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=27, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=395; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=27, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=395; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=616; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=27, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=395; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=27, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=395; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=27, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=395; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=44, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=611; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=93, max_features=None, min_samples_leaf=7, min_samples_split=13, n_estimators=558; total time=   0.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=93, max_features=None, min_samples_leaf=7, min_samples_split=13, n_estimators=558; total time=   1.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=93, max_features=None, min_samples_leaf=7, min_samples_split=13, n_estimators=558; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=44, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=611; total time=   0.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=93, max_features=None, min_samples_leaf=7, min_samples_split=13, n_estimators=558; total time=   1.0s
# [CV] END bootstrap=True, criterion=entropy, max_depth=93, max_features=None, min_samples_leaf=7, min_samples_split=13, n_estimators=558; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=44, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=611; total time=   0.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=319; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=44, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=611; total time=   0.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=44, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=611; total time=   0.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=821; total time=   0.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=319; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=821; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=821; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=821; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=319; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=319; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=821; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=319; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=91, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=90; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=91, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=90; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=91, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=90; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=91, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=90; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=91, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=90; total time=   0.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=774; total time=   0.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=774; total time=   0.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=774; total time=   0.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=774; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=570; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=570; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=774; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=570; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=570; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=570; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=280; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=441; total time=   0.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=441; total time=   0.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=441; total time=   0.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=441; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=280; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=441; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=280; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=280; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=280; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=829; total time=   1.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=829; total time=   1.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=829; total time=   1.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=829; total time=   1.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=829; total time=   1.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=87, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=267; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=87, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=267; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=87, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=267; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=87, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=267; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=788; total time=   1.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=87, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=267; total time=   0.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=788; total time=   2.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=788; total time=   1.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=788; total time=   1.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=788; total time=   1.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=86, max_features=None, min_samples_leaf=7, min_samples_split=18, n_estimators=613; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=798; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=86, max_features=None, min_samples_leaf=7, min_samples_split=18, n_estimators=613; total time=   1.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=86, max_features=None, min_samples_leaf=7, min_samples_split=18, n_estimators=613; total time=   1.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=86, max_features=None, min_samples_leaf=7, min_samples_split=18, n_estimators=613; total time=   1.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=86, max_features=None, min_samples_leaf=7, min_samples_split=18, n_estimators=613; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=798; total time=   1.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=798; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=38, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=731; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=38, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=731; total time=   0.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=798; total time=   1.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=798; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=38, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=731; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=38, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=731; total time=   0.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=38, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=731; total time=   0.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=sqrt, min_samples_leaf=6, min_samples_split=13, n_estimators=605; total time=   0.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=71, max_features=None, min_samples_leaf=7, min_samples_split=8, n_estimators=239; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=71, max_features=None, min_samples_leaf=7, min_samples_split=8, n_estimators=239; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=sqrt, min_samples_leaf=6, min_samples_split=13, n_estimators=605; total time=   0.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=sqrt, min_samples_leaf=6, min_samples_split=13, n_estimators=605; total time=   0.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=sqrt, min_samples_leaf=6, min_samples_split=13, n_estimators=605; total time=   0.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=71, max_features=None, min_samples_leaf=7, min_samples_split=8, n_estimators=239; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=sqrt, min_samples_leaf=6, min_samples_split=13, n_estimators=605; total time=   0.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=71, max_features=None, min_samples_leaf=7, min_samples_split=8, n_estimators=239; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=71, max_features=None, min_samples_leaf=7, min_samples_split=8, n_estimators=239; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=79, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=274; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=79, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=274; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=794; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=79, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=274; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=794; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=794; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=79, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=274; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=794; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=79, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=274; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=794; total time=   1.0s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=436; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=436; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=436; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=53, max_features=None, min_samples_leaf=6, min_samples_split=10, n_estimators=741; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=436; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=53, max_features=None, min_samples_leaf=6, min_samples_split=10, n_estimators=741; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=436; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=53, max_features=None, min_samples_leaf=6, min_samples_split=10, n_estimators=741; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=53, max_features=None, min_samples_leaf=6, min_samples_split=10, n_estimators=741; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=53, max_features=None, min_samples_leaf=6, min_samples_split=10, n_estimators=741; total time=   1.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=691; total time=   1.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=96, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=452; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=691; total time=   0.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=96, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=452; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=691; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=691; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=96, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=452; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=65, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=691; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=96, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=452; total time=   0.7s
# [CV] END bootstrap=False, criterion=entropy, max_depth=96, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=452; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=62, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=488; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=62, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=488; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=62, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=488; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=62, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=488; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=62, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=488; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=173; total time=   0.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=173; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=173; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=173; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=95, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=173; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=89, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=452; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=26, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=933; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=26, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=933; total time=   1.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=89, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=452; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=26, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=933; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=89, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=452; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=26, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=933; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=26, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=933; total time=   1.8s
# [CV] END bootstrap=True, criterion=entropy, max_depth=89, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=452; total time=   0.6s
# [CV] END bootstrap=True, criterion=entropy, max_depth=89, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=452; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=828; total time=   0.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=828; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=828; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=28, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=978; total time=   1.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=28, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=978; total time=   1.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=28, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=978; total time=   1.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=28, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=978; total time=   2.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=660; total time=   0.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=828; total time=   0.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=28, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=978; total time=   2.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=828; total time=   1.0s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=9, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=660; total time=   0.6s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=660; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=282; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=282; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=282; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=282; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=660; total time=   0.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=282; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=81, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=161; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=98, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=660; total time=   0.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=81, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=161; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=81, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=161; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=81, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=161; total time=   0.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=81, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=161; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=108, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=387; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=108, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=387; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=108, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=387; total time=   0.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=44, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=210; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=108, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=387; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=108, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=387; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=969; total time=   1.7s
# [CV] END bootstrap=False, criterion=entropy, max_depth=44, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=210; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=969; total time=   1.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=969; total time=   1.7s
# [CV] END bootstrap=False, criterion=entropy, max_depth=44, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=210; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=969; total time=   1.7s
# [CV] END bootstrap=False, criterion=entropy, max_depth=44, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=210; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=969; total time=   1.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=23, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=184; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=23, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=184; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=44, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=210; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=23, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=184; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=23, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=184; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=23, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=184; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=326; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=326; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=326; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=326; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=326; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=3, min_samples_split=15, n_estimators=719; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=3, min_samples_split=15, n_estimators=719; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=3, min_samples_split=15, n_estimators=719; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=3, min_samples_split=15, n_estimators=719; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=42, max_features=None, min_samples_leaf=3, min_samples_split=15, n_estimators=719; total time=   1.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=13, max_features=None, min_samples_leaf=1, min_samples_split=18, n_estimators=221; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=13, max_features=None, min_samples_leaf=1, min_samples_split=18, n_estimators=221; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=13, max_features=None, min_samples_leaf=1, min_samples_split=18, n_estimators=221; total time=   0.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=102, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=102, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=13, max_features=None, min_samples_leaf=1, min_samples_split=18, n_estimators=221; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=13, max_features=None, min_samples_leaf=1, min_samples_split=18, n_estimators=221; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=878; total time=   1.8s
# [CV] END bootstrap=False, criterion=entropy, max_depth=102, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=148; total time=   0.1s
# [CV] END bootstrap=False, criterion=entropy, max_depth=102, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=102, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=230; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=230; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=878; total time=   1.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=878; total time=   1.8s
# [CV] END bootstrap=False, criterion=gini, max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=230; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=230; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=878; total time=   1.9s
# [CV] END bootstrap=True, criterion=gini, max_depth=69, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=305; total time=   0.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=230; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=69, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=305; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=69, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=305; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=69, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=305; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=69, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=305; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=37, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=878; total time=   2.1s
# [CV] END bootstrap=True, criterion=entropy, max_depth=27, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=921; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=27, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=921; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=27, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=921; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=27, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=921; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=27, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=921; total time=   1.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=688; total time=   1.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=688; total time=   1.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=688; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=978; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=978; total time=   1.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=688; total time=   1.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=978; total time=   1.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=688; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=978; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=978; total time=   1.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=867; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=22, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=734; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=867; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=22, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=734; total time=   0.9s
# [CV] END bootstrap=True, criterion=entropy, max_depth=22, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=734; total time=   0.9s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=16, n_estimators=141; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=16, n_estimators=141; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=867; total time=   1.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=867; total time=   1.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=16, n_estimators=141; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=57, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=867; total time=   1.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=16, n_estimators=141; total time=   0.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=22, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=734; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=16, n_estimators=141; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=313; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=22, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=734; total time=   0.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=313; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=313; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=313; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=24, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=313; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=18, n_estimators=741; total time=   1.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=18, n_estimators=741; total time=   1.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=18, n_estimators=741; total time=   1.5s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=18, n_estimators=741; total time=   1.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=41, max_features=None, min_samples_leaf=6, min_samples_split=18, n_estimators=741; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=14, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=926; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=14, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=926; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=14, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=926; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=14, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=926; total time=   1.7s
# [CV] END bootstrap=True, criterion=entropy, max_depth=14, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=926; total time=   1.7s
# ...
# [CV] END bootstrap=False, criterion=gini, max_depth=71, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=328; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=71, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=328; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=71, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=328; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=778; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=778; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=778; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=778; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=68, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=445; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=68, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=445; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=778; total time=   1.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=68, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=445; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=68, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=445; total time=   1.0s
# [CV] END bootstrap=False, criterion=gini, max_depth=68, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=445; total time=   1.0s
# [CV] END bootstrap=False, criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=28, max_features=sqrt, min_samples_leaf=7, min_samples_split=15, n_estimators=784; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=28, max_features=sqrt, min_samples_leaf=7, min_samples_split=15, n_estimators=784; total time=   0.9s
# [CV] END bootstrap=False, criterion=entropy, max_depth=92, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=148; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=28, max_features=sqrt, min_samples_leaf=7, min_samples_split=15, n_estimators=784; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=28, max_features=sqrt, min_samples_leaf=7, min_samples_split=15, n_estimators=784; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=28, max_features=sqrt, min_samples_leaf=7, min_samples_split=15, n_estimators=784; total time=   1.0s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=235; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=235; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=235; total time=   0.5s
# [CV] END bootstrap=True, criterion=entropy, max_depth=104, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=264; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=235; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=66, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=235; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=61, max_features=None, min_samples_leaf=5, min_samples_split=5, n_estimators=614; total time=   1.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=61, max_features=None, min_samples_leaf=5, min_samples_split=5, n_estimators=614; total time=   1.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=61, max_features=None, min_samples_leaf=5, min_samples_split=5, n_estimators=614; total time=   1.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=61, max_features=None, min_samples_leaf=5, min_samples_split=5, n_estimators=614; total time=   1.3s
# [CV] END bootstrap=False, criterion=gini, max_depth=61, max_features=None, min_samples_leaf=5, min_samples_split=5, n_estimators=614; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=104, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=264; total time=   0.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=104, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=264; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=104, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=264; total time=   0.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=104, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=264; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=log2, min_samples_leaf=9, min_samples_split=11, n_estimators=541; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=442; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=log2, min_samples_leaf=9, min_samples_split=11, n_estimators=541; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=442; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=log2, min_samples_leaf=9, min_samples_split=11, n_estimators=541; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=log2, min_samples_leaf=9, min_samples_split=11, n_estimators=541; total time=   0.8s
# [CV] END bootstrap=True, criterion=gini, max_depth=84, max_features=log2, min_samples_leaf=9, min_samples_split=11, n_estimators=541; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=442; total time=   0.7s
# [CV] END bootstrap=False, criterion=gini, max_depth=75, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=388; total time=   0.4s
# [CV] END bootstrap=False, criterion=gini, max_depth=75, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=388; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=442; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=75, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=388; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=75, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=388; total time=   0.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=75, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=388; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=16, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=442; total time=   0.6s
# [CV] END bootstrap=False, criterion=entropy, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=18, n_estimators=560; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=log2, min_samples_leaf=3, min_samples_split=13, n_estimators=231; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=log2, min_samples_leaf=3, min_samples_split=13, n_estimators=231; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=log2, min_samples_leaf=3, min_samples_split=13, n_estimators=231; total time=   0.4s
# [CV] END bootstrap=False, criterion=entropy, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=18, n_estimators=560; total time=   0.6s
# [CV] END bootstrap=True, criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=175; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=log2, min_samples_leaf=3, min_samples_split=13, n_estimators=231; total time=   0.3s
# [CV] END bootstrap=True, criterion=gini, max_depth=54, max_features=log2, min_samples_leaf=3, min_samples_split=13, n_estimators=231; total time=   0.3s
# [CV] END bootstrap=False, criterion=entropy, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=18, n_estimators=560; total time=   0.7s
# [CV] END bootstrap=False, criterion=entropy, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=18, n_estimators=560; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=175; total time=   0.2s
# [CV] END bootstrap=False, criterion=entropy, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=18, n_estimators=560; total time=   0.7s
# [CV] END bootstrap=True, criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=175; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=175; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=83, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=175; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=48, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=397; total time=   0.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=48, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=397; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=48, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=397; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=48, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=397; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=22, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=878; total time=   1.0s
# [CV] END bootstrap=True, criterion=gini, max_depth=22, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=878; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=22, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=878; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=48, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=397; total time=   0.5s
# [CV] END bootstrap=True, criterion=gini, max_depth=22, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=878; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=22, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=878; total time=   1.5s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=983; total time=   1.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=983; total time=   1.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=983; total time=   1.2s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=983; total time=   1.1s
# [CV] END bootstrap=False, criterion=gini, max_depth=72, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=983; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=45, max_features=None, min_samples_leaf=3, min_samples_split=19, n_estimators=96; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=45, max_features=None, min_samples_leaf=3, min_samples_split=19, n_estimators=96; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=45, max_features=None, min_samples_leaf=3, min_samples_split=19, n_estimators=96; total time=   0.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=935; total time=   1.4s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=935; total time=   1.4s
# [CV] END bootstrap=True, criterion=gini, max_depth=45, max_features=None, min_samples_leaf=3, min_samples_split=19, n_estimators=96; total time=   0.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=45, max_features=None, min_samples_leaf=3, min_samples_split=19, n_estimators=96; total time=   0.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=935; total time=   1.3s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=935; total time=   1.2s
# [CV] END bootstrap=True, criterion=entropy, max_depth=67, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=935; total time=   1.2s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=705; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=705; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=705; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=705; total time=   1.1s
# [CV] END bootstrap=True, criterion=gini, max_depth=23, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=705; total time=   1.1s
#
# Best hyperparameters found:
# {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 52, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 19, 'n_estimators': 84}
#
# Best cross-validation score:
# 0.824386880724909
#
# Best Random Forest Classifier:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=52,
#                        min_samples_leaf=2, min_samples_split=19,
#                        n_estimators=84, random_state=0)
#
# Accuracy on test set:
# 0.8379888268156425
#
# Classification Report on test set:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88       115
#            1       0.81      0.72      0.76        64
#
#     accuracy                           0.84       179
#    macro avg       0.83      0.81      0.82       179
# weighted avg       0.84      0.84      0.84       179

# %% [markdown]
# Preparing submission

# %%
titanic_test_data = pd.read_csv("test.csv")

# %%
titanic_test_data = titanic_test_data.drop(columns=["Cabin", "Name", "Ticket"])

# %%
colums_with_missing_values = titanic_test_data.columns[titanic_test_data.isnull().any()]
print(colums_with_missing_values)
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
titanic_test_data["Fare"].fillna(value=0, inplace=True)

# %%
fare_cats_bins = list(range(0, 301, 50))
fare_cats_bins_with_inf = fare_cats_bins + [np.inf]
titanic_test_data["Fare_cat"] = pd.cut(
    titanic_test_data["Fare"],
    include_lowest=True,
    bins=pd.Series(fare_cats_bins_with_inf),
    labels=pd.Series(fare_cats_bins),
)
titanic_test_data["Fare_cat"] = titanic_test_data["Fare_cat"].astype(int)

# %%
titanic_test_data_transformed = columnTransformer.transform(titanic_test_data)

# %%
y_submission = best_random_forest.predict(titanic_test_data_transformed)

# %%
submission_df = pd.DataFrame(
    titanic_test_data["PassengerId"],
    columns=["PassengerId"],
    index=titanic_test_data.index,
)

# %%
submission_df['Survived'] = y_submission
